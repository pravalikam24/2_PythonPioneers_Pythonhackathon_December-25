# %%
import os

os.chdir(
    r"C:\Users\EM\OneDrive\Desktop\DA course\Python\Hackathon\Flatten_Covid19_Dataset-20251217T221337Z-3-001\Flatten_Covid19_Dataset"
)

# %%
print(os.getcwd())
print(os.listdir())
# Out:
# C:\Users\EM\OneDrive\Desktop\DA course\Python\Hackathon\Flatten_Covid19_Dataset-20251217T221337Z-3-001\Flatten_Covid19_Dataset
# ['ontario_covid_combined_cleaned.csv', 'schema_1_ontario_final.csv', 'schema_2_ontario_final.csv', 'schema_3_ontario_final.csv']

# %%
import pandas as pd

# Reading the file schema_1_ontario_final
df_schema1 = pd.read_csv("schema_1_ontario_final.csv")

# %%
#Reading the files
df_schema2=pd.read_csv("schema_2_ontario_final.csv")
#Reading the file schema_3_ontario_final
df_schema3=pd.read_csv("schema_3_ontario_final.csv")

# %%
#combine 3 schema files into a single file
df_combined = pd.concat([df_schema1, df_schema2, df_schema3], ignore_index=True, sort=False)

# %%
#Renaming age_1 to age_category as this column has age category rather than age
df_combined.rename(columns={'age_1': 'age_category'}, inplace=True)

# %%
df_combined.head()
# Out:
#    week  fsa probable vulnerable is_most_recent fever_chills_shakes cough  \
# 0  13.0  L4C        n          n              y                   n     n
# 1  13.0  P1H        y          y              y                   n     n
# 2  14.0  N2J        n          y              y                   n     n
# 3  13.0  N1G        n          n              y                   n     n
# 4  13.0  M1P        n          y              n                   n     n
#
#   shortness_of_breath over_60 any_medical_conditions  ...  \
# 0                   n       n                      n  ...
# 1                   n       y                      y  ...
# 2                   n       y                      n  ...
# 3                   n       n                      n  ...
# 4                   n       n                      y  ...
#
#   contact_in_household tested covid_results_date covid_positive  \
# 0                  NaN    NaN                NaN            NaN
# 1                  NaN    NaN                NaN            NaN
# 2                  NaN    NaN                NaN            NaN
# 3                  NaN    NaN                NaN            NaN
# 4                  NaN    NaN                NaN            NaN
#
#   mental_health_impact travel_work_school self_isolating media_channels  \
# 0                  NaN                NaN            NaN            NaN
# 1                  NaN                NaN            NaN            NaN
# 2                  NaN                NaN            NaN            NaN
# 3                  NaN                NaN            NaN            NaN
# 4                  NaN                NaN            NaN            NaN
#
#   financial_obligations_impact tobacco_usage
# 0                          NaN           NaN
# 1                          NaN           NaN
# 2                          NaN           NaN
# 3                          NaN           NaN
# 4                          NaN           NaN
#
# [5 rows x 29 columns]

# %%
df_combined.columns
# Out:
# Index(['week', 'fsa', 'probable', 'vulnerable', 'is_most_recent',
#        'fever_chills_shakes', 'cough', 'shortness_of_breath', 'over_60',
#        'any_medical_conditions', 'travel_outside_canada',
#        'contact_with_illness', 'symptoms', 'conditions', 'ethnicity', 'sex',
#        'needs', 'age_category', 'month', 'contact_in_household', 'tested',
#        'covid_results_date', 'covid_positive', 'mental_health_impact',
#        'travel_work_school', 'self_isolating', 'media_channels',
#        'financial_obligations_impact', 'tobacco_usage'],
#       dtype='object')

# %%
import os
print(os.getcwd())
# Out:
# C:\Users\EM\OneDrive\Desktop\DA course\Python\Hackathon\Flatten_Covid19_Dataset-20251217T221337Z-3-001\Flatten_Covid19_Dataset

# %%
df_combined.to_csv(
    "ontario_covid_combined_cleaned.csv",
    index=False
)
